# %% [markdown]
# ### Notebook 1:  Clustering con K-means
# En este notebook vamos a implementar el algoritmo de clustering K-means en R. El objetivo es entender como funciona este algoritmo y  aprender a utilizarlo con un ejemplo simple. Se incluye además la estrategia para definir el número de grupos k. Al final se propone un ejercicio con nuevos datos, con el fin de aprender a utilizar el algoritmo.

# %%
library(cluster)
library(ggplot2)

#ruta datos
#lee datos del archivo de texto como una matriz. La primera #columna se utiliza como vector de nombres de las filas
datos <-read.table("milk1.dat",row.names=1,dec=".",header=TRUE)
summary(datos)
boxplot(datos)
# Out:
#      WATER          PROTEIN            FAT           LACTOSE
#  Min.   :44.90   Min.   : 0.600   Min.   : 1.00   Min.   :0.000
#  1st Qu.:71.30   1st Qu.: 3.000   1st Qu.: 3.40   1st Qu.:2.700
#  Median :82.00   Median : 5.900   Median : 6.30   Median :4.700
#  Mean   :78.18   Mean   : 6.212   Mean   :10.31   Mean   :4.132
#  3rd Qu.:87.70   3rd Qu.: 9.700   3rd Qu.:13.10   3rd Qu.:5.600
#  Max.   :90.40   Max.   :12.300   Max.   :42.00   Max.   :6.900
#       ASH
#  Min.   :0.1000
#  1st Qu.:0.5300
#  Median :0.8000
#  Mean   :0.8632
#  3rd Qu.:1.1000
#  Max.   :2.3000
# plot without title

# %% [markdown]
# **Ejercicio 1:** describa los datos y discuta la pertinencia de realizar un análisis de clustering o agrupamiento
#
# #### Es pertinente ya que a simple vista no hay mayor información sobre características propias de los mamíferos.
# #### Además debido a que son múltiples variables, no se puede ordenar o clasificar por variables separadas.

# %%
#ingresar valor de k0 
k0=3
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
#grafica los datos coloreados con el grupo asignado en planos de pares de variables
pairs(datos,col=cl$cluster)
# Out:
# plot without title

# %% [markdown]
# **Ejercicio 2:** Interprete y comente los resultados obtenidos.
#
# ##### Haciendo análisis de las variables en pares, podemos deducir hacia donde se inclinan los datos, por ejemplo en fila 1 columna 2, los datos rojos poseen mayor concentración de agua y baja proteína, mientras el grupo verde se mantiene en un promedio de proteina y agua, sin embargo, el grupo de color negro casi no posee agua y tiene valores altos de proteína. En la celda de la fila 2 y columna 3, el grupo de color rojo se mantiene con altos niveles de proteína y la grasa varía en cantidad media hacia alta, mientras el color negro se inclina por proteína.

# %%
#Análisis de Componentes Principales para graficar los grupos obtenidos
#Calcula plano de componentes principales y grafica las observaciones con el número de su grupo
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
#grafica los centros de cada grupo en el plano de componentes principales utilizando colores distintos
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#    Comp.1        Comp.2      Comp.3      Comp.4      Comp.5
# 1  -3.528390e+00 -2.28086300  0.12858522 -0.43283034 -0.249417356
# 2   4.710687e-01  0.39033806 -0.10706204 -0.10838491 -0.029962683
# 3   1.390928e+00 -0.01265979 -0.11692864  0.28707863 -0.004502066
# 4  -9.965577e-05  0.78813837  0.33407028  0.05686035 -0.056423047
# 5   2.297298e+00 -0.67823805 -0.06514599 -0.08347041  0.004788585
# 6   5.050683e-01  0.08823533 -0.00838298 -0.13377446  0.083805910
# 7  -4.133773e+00 -2.20080107  0.06721481  0.37461533  0.190501442
# 8   2.060294e+00 -1.01919913  0.76243569  0.51009117  0.029381555
# 9  -2.555018e-01  0.28737324  0.88185687  0.01309988 -0.016484103
# 10 -2.278834e+00  0.32751924 -0.20857884 -0.08671687  0.037691843
# 11 -5.100844e-02  0.47013584  0.35567618 -1.05096967  0.159792918
# 12  1.332785e+00  0.22326342 -0.01492711  0.18520099 -0.019506445
# 13 -2.892787e+00  0.72112072 -0.05594256  0.27617203  0.054319487
# 14  1.282742e+00  0.62266660 -0.25378522 -0.06514797 -0.044486332
# 15 -2.798474e+00  2.28879316 -0.16191407  0.39442116 -0.021718684
# 16  2.165668e+00 -0.23331073  0.01072184  0.16788582 -0.016027350
# 17 -9.828286e-01  0.72523875  0.33155190 -0.16959000 -0.063456145
# 18  2.435175e+00 -0.23147753 -0.33015028 -0.30766379  0.048184402
# 19 -1.309609e+00  0.77403221 -0.15970917 -0.01548456 -0.064370973
# 20  3.022937e-01 -1.07987759 -1.00459374  0.11409300  0.000905093
# K-means clustering with 20 clusters of sizes 1, 2, 1, 1, 2, 1, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 1, 1
#
# Cluster means:
#    WATER PROTEIN   FAT LACTOSE   ASH
# 1  44.90   10.60 34.90    0.90 0.530
# 2  81.80    6.10  6.15    4.80 0.920
# 3  86.20    3.00  4.80    5.30 0.700
# 4  82.80    7.10  5.10    3.70 1.100
# 5  88.45    1.80  3.10    6.20 0.210
# 6  82.10    5.90  7.90    4.70 0.780
# 7  46.40    9.70 42.00    0.00 0.850
# 8  90.40    0.60  4.50    4.40 0.100
# 9  81.90    7.40  7.20    2.70 0.850
# 10 65.35   10.55 20.00    2.55 1.400
# 11 81.60   10.10  6.30    4.40 0.750
# 12 87.10    3.70  3.30    5.20 0.755
# 13 64.80   11.10 21.20    1.60 1.700
# 14 86.90    4.80  1.70    5.70 0.900
# 15 71.30   12.30 13.10    1.90 2.300
# 16 90.15    1.85  1.60    5.85 0.435
# 17 76.30    9.30  9.50    3.00 1.200
# 18 90.10    2.60  1.00    6.90 0.350
# 19 72.50    9.20 12.60    3.30 1.400
# 20 70.70    3.60 17.60    5.60 0.630
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#         18          5          5         16          8         12         14
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          6          9         11          2         12         16          4
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          3          2         17         20         15         19         10
#   REINDEER      WHALE       SEAL    DOLPHIN
#         10         13          7          1
#
# Within cluster sum of squares by cluster:
#  [1] 0.00000 0.72520 0.00000 0.00000 0.72680 0.00000 0.00000 0.00000 0.00000
# [10] 0.83500 0.00000 1.14405 0.00000 0.00000 0.00000 0.41745 0.00000 0.00000
# [19] 0.00000 0.00000
#  (between_SS / total_SS =  99.9 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title

# %% [markdown]
# **Ejercicio 3:** Repita el procedimiento considerando 2 y 4 grupos. Discuta sus resultados.

# %% [markdown]
# ### Para 2 grupos

# %%
k0=2
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
pairs(datos,col=cl$cluster)
# Out:
# plot without title

# %%
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1    Comp.2      Comp.3      Comp.4      Comp.5
# 1 -2.364801 -0.14031964 -0.20043965  0.06719411 -0.0017996632
# 2  1.112848  0.06603277  0.09432454 -0.03162076  0.0008469003
# K-means clustering with 2 clusters of sizes 8, 17
#
# Cluster means:
#      WATER  PROTEIN       FAT  LACTOSE       ASH
# 1 62.66250 9.700000 22.675000 2.300000 1.2762500
# 2 85.48824 4.570588  4.488235 4.994118 0.6688235
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          2          2          2          2          2          2          2
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          2          2          2          2          2          2          2
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          2          2          2          1          1          1          1
#   REINDEER      WHALE       SEAL    DOLPHIN
#          1          1          1          1
#
# Within cluster sum of squares by cluster:
# [1] 1664.9235  521.8994
#  (between_SS / total_SS =  68.8 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title

# %% [markdown]
# ### Para 4 grupos

# %%
k0=4
cl<-kmeans(datos,k0,iter.max=1000,nstart=10)
pairs(datos,col=cl$cluster)
# Out:
# plot without title

# %% [markdown]
# ### Los datos para 2 grupos se ven adheridos de cierta forma al grupo que se encontraba más cercano a el, es decir, con propiedades más parecidas.
# ### Los datos para 4 grupos hace que los datos se separen, aplicando un tipo de distribución por semejanza de características

# %%
res <- princomp(datos, cor=TRUE)
res2 <- predict(res,cl$centers)
res2
cl
biplot(res,xlabs=cl$cluster)
points(res2[,1:2],col=1:k0,pch=19)
# Out:
#   Comp.1      Comp.2     Comp.3       Comp.4      Comp.5
# 1  0.02253818  0.4485425  0.240092595 -0.21444910  0.006758595
# 2  1.87606405 -0.2017241 -0.007713097  0.09635908 -0.003291286
# 3 -1.87604083  0.5598512 -0.299886203  0.09929465  0.007419768
# 4 -3.83108138 -2.2408320  0.097900012 -0.02910750 -0.029457957
# K-means clustering with 4 clusters of sizes 7, 10, 6, 2
#
# Cluster means:
#      WATER   PROTEIN      FAT  LACTOSE       ASH
# 1 81.18571  7.428571  6.90000 4.014286 0.9314286
# 2 88.50000  2.570000  2.80000 5.680000 0.4850000
# 3 68.33333  9.550000 17.41667 2.916667 1.4716667
# 4 45.65000 10.150000 38.45000 0.450000 0.6900000
#
# Clustering vector:
#      HORSE  ORANGUTAN     MONKEY     DONKEY      HIPPO      CAMEL      BISON
#          2          2          2          2          2          2          2
#    BUFFALO GUINEA_PIG        CAT        FOX      LLAMA       MULE        PIG
#          1          1          1          1          2          2          1
#      ZEBRA      SHEEP        DOG   ELEPHANT     RABBIT        RAT       DEER
#          2          1          1          3          3          3          3
#   REINDEER      WHALE       SEAL    DOLPHIN
#          3          3          4          4
#
# Within cluster sum of squares by cluster:
# [1]  63.53491  59.41225 191.74708  27.19120
#  (between_SS / total_SS =  95.1 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"
# plot without title

# %%
#Estrategia para elegir K, el numero de grupos
#J suma cuadrado de las distancias por cada k utilizado
#K-means
J<-rep(0,20)
fin_iter<-20


for (k in 1:fin_iter){
     cl<-kmeans(datos,k,iter.max=1000,nstart=10)
	 J[k]<-cl$tot.withinss
}


plot(1:fin_iter,J,xlab="k",ylab="J",type="p",main="J v/s k en k-means",col=2)
# Out:
# Plot with title “J v/s k en k-means”

# %% [markdown]
# **Ejercicio 4:** de acuerdo al gráfico obtenido, cuál es el valor de K mas apropiado?
# Agregue código para automatizar este criterio.

# %%
J<-rep(0,20)
fin_iter<-20
dif_k = 0
dif_k1=0
tasa_k = 0
comp=0
k_optimo = 0

for (k in 1:fin_iter){
     cl<-kmeans(datos,k,iter.max=1000,nstart=10)
     J[k]<-cl$tot.withinss
    if(k!=1 && k!=20){
        dif_k = abs(J[k]-J[k-1])
        dif_k1 = J[k]-J[k+1]
        tasa_k = dif_k/dif_k1




    }
    if(tasa_k > comp ){
        comp = tasa_k
         k_optimo = k+1
    }

}

print(k_optimo)
# Out:
# [1] 3

# %% [markdown]
# ## De aquí observamos que el número de grupos es para el valor k=3 grupos.

# %% [markdown]
# **Ejercicio 5:** Realice un análisis de clustering con el conjunto de datos iris.csv. Considere para ello las cuatro características numéricas que se proporcionan. Luego realice un análisis respecto a la etiqueta de cada observación.
# Interprete sus resultados.
